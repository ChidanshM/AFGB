# %% [markdown]
# # 01-PyBA:
# ## 21

# %% [markdown]
# #### 1. Add the current date to the text file `today.txt` as a string.

# %%
from datetime import date
with open('today.txt','w') as f:
	f.write(str(date.today()))

# %% [markdown]
# #### 2. Read the text file today.txt into the string `today_string`

# %%
with open('today.txt','r') as f:
	today_string=f.read()
today_string
# Out:
# '2024-04-02'

# %% [markdown]
# #### 3. Parse the date from `today_string`.

# %%
date.fromisoformat(today_string)
# Out:
# datetime.date(2024, 4, 2)

# %% [markdown]
# #### 4. List the files in your current directory

# %%
# !ls
# Out:
# afgb-01-01.ipynb  afgb-01-09.ipynb  afgb-01-17.ipynb  afgb-01-25.ipynb
# afgb-01-02.ipynb  afgb-01-10.ipynb  afgb-01-18.ipynb  books.csv
# afgb-01-03.ipynb  afgb-01-11.ipynb  afgb-01-19.ipynb  books.db
# afgb-01-04.ipynb  afgb-01-12.ipynb  afgb-01-20.ipynb  docs
# afgb-01-05.ipynb  afgb-01-13.ipynb  afgb-01-21.ipynb  test.txt
# afgb-01-06.ipynb  afgb-01-14.ipynb  afgb-01-22.ipynb  today.txt
# afgb-01-07.ipynb  afgb-01-15.ipynb  afgb-01-23.ipynb  webpage.html
# afgb-01-08.ipynb  afgb-01-16.ipynb  afgb-01-24.ipynb  zoo.py

# %% [markdown]
# #### 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os

ls = os.listdir('..')
ls
# Out:
# ['track.md',
#  'git.ipynb',
#  'README.md',
#  '04_PyPAdvnc',
#  '01_PyBasic',
#  '.git',
#  '03_PyPBasic']

# %% [markdown]
# #### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing
import time
import random
from datetime import datetime as dt

# %%
def print_current_time():
	time.sleep(random.randint(1, 5))
	_=dt.now()
	print(f'{_.hour}:{_.minute}:{_.second}.{_.microsecond}')

# %%
if __name__ == '__main__':
	processes = []
	for _ in range(3):
		p = multiprocessing.Process(target=print_current_time)
		processes.append(p)
		p.start()
	for process in processes:
		process.join()
# Out:
# 21:15:23.990292
# 21:15:25.18418
# 21:15:26.6444

# %% [markdown]
# #### 7. Create a date object of your day of birth.

# %%
day_of_birth=date(1991,2,20);day_of_birth
# Out:
# datetime.date(1991, 2, 20)

# %% [markdown]
# #### 8. What day of the week was your day of birth?

# %%
day_of_birth.strftime("%A")
# Out:
# 'Wednesday'

# %% [markdown]
# #### 9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta as td
day_of_birth+td(days=10000)
# Out:
# datetime.date(2018, 7, 8)
